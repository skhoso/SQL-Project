# %% [markdown]
# ## Data Cleanup
#
# Now that we loaded the data from switchup website, we need to clean data and prepare them to insert into
# database.
#
# Activities:
# * Remove HTML like codes from fields such as Description
# * Check for NULL values and decide what to do with them

# %%
#imports
import pandas as pd
import re

# %%
# Load CSV files we downloaded, in order to clean them
badges = pd.read_csv('badges.csv')
comments = pd.read_csv('comments.csv')
schools = pd.read_csv('schools.csv')
locations = pd.read_csv('locations.csv')
courses = pd.read_csv('courses.csv')

# %% [markdown]
# #### Remove HTML

# %%
def strip_html(str):
    return re.sub('<[^<]+?>', '', str)

# %%
schools['description'] = schools.apply(lambda r: strip_html(r['description']), axis=1)
schools.head()
# Out:
#    Unnamed: 0                                            website  \
# 0           0                                www.ironhack.com/en
# 1           0                                      appacademy.io
# 2           0  www.springboard.com/?utm_source=switchup&utm_m...
# 3           0  anyonecanlearntocode.com/?utm_source=switchup&...
# 4           0                                   learningfuze.com
#
#                                          description  \
# 0  Ironhack is a global tech school with 9 campus...
# 1  Founded in 2012, App Academy is a world-renown...
# 2  Springboard is an online learning platform tha...
# 3  Actualize is a coding bootcamp that values qua...
# 4  LearningFuze is an immersive, 14-week web deve...
#
#                                              LogoUrl        school  school_id
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...      ironhack      10828
# 1  https://d92mrp7hetgfk.cloudfront.net/images/si...   app-academy      10525
# 2  https://d92mrp7hetgfk.cloudfront.net/images/si...   springboard      11035
# 3  https://d92mrp7hetgfk.cloudfront.net/images/si...     actualize      10505
# 4  https://d92mrp7hetgfk.cloudfront.net/images/si...  learningfuze      10862

# %%
badges['description'] = badges.apply(lambda r: strip_html(r['description']), axis=1)
badges.head()
# Out:
#    Unnamed: 0               name            keyword  \
# 0           0   Available Online   available_online
# 1           1  Verified Outcomes  verified_outcomes
# 2           2   Flexible Classes   flexible_classes
# 3           0   Available Online   available_online
# 4           1   Flexible Classes   flexible_classes
#
#                                          description       school  school_id
# 0                 School offers fully online courses     ironhack      10828
# 1  School publishes a third-party verified outcom...     ironhack      10828
# 2        School offers part-time and evening classes     ironhack      10828
# 3                 School offers fully online courses  app-academy      10525
# 4        School offers part-time and evening classes  app-academy      10525

# %%
comments.head()
# Out:
#    Unnamed: 0      id          name  anonymous hostProgramName  \
# 0           0  306215     Anonymous       True             NaN
# 1           1  306068     Anonymous       True             NaN
# 2           2  305297   Utku Cikmaz      False             NaN
# 3           3  305278  Nirmal Hodge      False             NaN
# 4           4  305231     Anonymous       True             NaN
#
#    graduatingYear isAlumni                  jobTitle  \
# 0          2023.0     True                       NaN
# 1          2023.0    False    Full stack development
# 2          2023.0    False  Full Stack Web Developer
# 3          2023.0    False          Product Designer
# 4          2023.0    False                       NaN
#
#                                           tagline  \
# 0  Transformative Experience: My Time at Ironhack
# 1                                 Now I can do it
# 2                                     It was good
# 3                         Ironhack 100% Worth It!
# 4                          Still waiting a refund
#
#                                                 body  ...   queryDate  \
# 0  <span class="truncatable"><p></p><p>Pros: 1)In...  ...  2023-11-06
# 1  <span class="truncatable"><p></p><p>7 months a...  ...  2023-10-31
# 2  <span class="truncatable"><p></p><p>The course...  ...  2023-10-02
# 3  <span class="truncatable"><p></p><p>I joined t...  ...  2023-09-30
# 4  <span class="truncatable"><p></p><p>Unfortunat...  ...  2023-09-28
#
#                     program             user overallScore comments  overall  \
# 0  Web Development Bootcamp  {'image': None}          4.0       []      4.0
# 1                       NaN  {'image': None}          5.0       []      5.0
# 2  Web Development Bootcamp  {'image': None}          4.0       []      5.0
# 3     UX/UI Design Bootcamp  {'image': None}          5.0       []      5.0
# 4  Web Development Bootcamp  {'image': None}          1.0       []      1.0
#
#   curriculum  jobSupport                                        review_body  \
# 0        4.0         4.0  Pros: 1)Intensive Learning 2)Real-World Projec...
# 1        5.0         5.0  7 months ago, I only had an idea about html an...
# 2        3.0         4.0  The course was great. Especially, Luis is a gr...
# 3        5.0         5.0  I joined the UX/ UI Bootcamp and to be honest ...
# 4        1.0         1.0  Unfortunately wouldn’t recommend it. Still wai...
#
#      school
# 0  ironhack
# 1  ironhack
# 2  ironhack
# 3  ironhack
# 4  ironhack
#
# [5 rows x 22 columns]

# %%
comments['body'] = comments.apply(lambda r: strip_html(r['body']), axis=1)
comments.head()
# Out:
#    Unnamed: 0      id          name  anonymous hostProgramName  \
# 0           0  306215     Anonymous       True             NaN
# 1           1  306068     Anonymous       True             NaN
# 2           2  305297   Utku Cikmaz      False             NaN
# 3           3  305278  Nirmal Hodge      False             NaN
# 4           4  305231     Anonymous       True             NaN
#
#    graduatingYear isAlumni                  jobTitle  \
# 0          2023.0     True                       NaN
# 1          2023.0    False    Full stack development
# 2          2023.0    False  Full Stack Web Developer
# 3          2023.0    False          Product Designer
# 4          2023.0    False                       NaN
#
#                                           tagline  \
# 0  Transformative Experience: My Time at Ironhack
# 1                                 Now I can do it
# 2                                     It was good
# 3                         Ironhack 100% Worth It!
# 4                          Still waiting a refund
#
#                                                 body  ...   queryDate  \
# 0  Pros: 1)Intensive Learning 2)Real-World Projec...  ...  2023-11-06
# 1  7 months ago, I only had an idea about html an...  ...  2023-10-31
# 2  The course was great. Especially, Luis is a gr...  ...  2023-10-02
# 3  I joined the UX/ UI Bootcamp and to be honest ...  ...  2023-09-30
# 4  Unfortunately wouldn’t recommend it. Still wai...  ...  2023-09-28
#
#                     program             user overallScore comments  overall  \
# 0  Web Development Bootcamp  {'image': None}          4.0       []      4.0
# 1                       NaN  {'image': None}          5.0       []      5.0
# 2  Web Development Bootcamp  {'image': None}          4.0       []      5.0
# 3     UX/UI Design Bootcamp  {'image': None}          5.0       []      5.0
# 4  Web Development Bootcamp  {'image': None}          1.0       []      1.0
#
#   curriculum  jobSupport                                        review_body  \
# 0        4.0         4.0  Pros: 1)Intensive Learning 2)Real-World Projec...
# 1        5.0         5.0  7 months ago, I only had an idea about html an...
# 2        3.0         4.0  The course was great. Especially, Luis is a gr...
# 3        5.0         5.0  I joined the UX/ UI Bootcamp and to be honest ...
# 4        1.0         1.0  Unfortunately wouldn’t recommend it. Still wai...
#
#      school
# 0  ironhack
# 1  ironhack
# 2  ironhack
# 3  ironhack
# 4  ironhack
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Decide About empty values

# %%
badges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   68 non-null     int64
#  1   name         68 non-null     object
#  2   keyword      68 non-null     object
#  3   description  68 non-null     object
#  4   school       68 non-null     object
#  5   school_id    68 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 3.3+ KB

# %%
comments.head()
# Out:
#    Unnamed: 0      id          name  anonymous hostProgramName  \
# 0           0  306215     Anonymous       True             NaN
# 1           1  306068     Anonymous       True             NaN
# 2           2  305297   Utku Cikmaz      False             NaN
# 3           3  305278  Nirmal Hodge      False             NaN
# 4           4  305231     Anonymous       True             NaN
#
#    graduatingYear isAlumni                  jobTitle  \
# 0          2023.0     True                       NaN
# 1          2023.0    False    Full stack development
# 2          2023.0    False  Full Stack Web Developer
# 3          2023.0    False          Product Designer
# 4          2023.0    False                       NaN
#
#                                           tagline  \
# 0  Transformative Experience: My Time at Ironhack
# 1                                 Now I can do it
# 2                                     It was good
# 3                         Ironhack 100% Worth It!
# 4                          Still waiting a refund
#
#                                                 body  ...   queryDate  \
# 0  Pros: 1)Intensive Learning 2)Real-World Projec...  ...  2023-11-06
# 1  7 months ago, I only had an idea about html an...  ...  2023-10-31
# 2  The course was great. Especially, Luis is a gr...  ...  2023-10-02
# 3  I joined the UX/ UI Bootcamp and to be honest ...  ...  2023-09-30
# 4  Unfortunately wouldn’t recommend it. Still wai...  ...  2023-09-28
#
#                     program             user overallScore comments  overall  \
# 0  Web Development Bootcamp  {'image': None}          4.0       []      4.0
# 1                       NaN  {'image': None}          5.0       []      5.0
# 2  Web Development Bootcamp  {'image': None}          4.0       []      5.0
# 3     UX/UI Design Bootcamp  {'image': None}          5.0       []      5.0
# 4  Web Development Bootcamp  {'image': None}          1.0       []      1.0
#
#   curriculum  jobSupport                                        review_body  \
# 0        4.0         4.0  Pros: 1)Intensive Learning 2)Real-World Projec...
# 1        5.0         5.0  7 months ago, I only had an idea about html an...
# 2        3.0         4.0  The course was great. Especially, Luis is a gr...
# 3        5.0         5.0  I joined the UX/ UI Bootcamp and to be honest ...
# 4        1.0         1.0  Unfortunately wouldn’t recommend it. Still wai...
#
#      school
# 0  ironhack
# 1  ironhack
# 2  ironhack
# 3  ironhack
# 4  ironhack
#
# [5 rows x 22 columns]

# %%
schools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   24 non-null     int64
#  1   website      24 non-null     object
#  2   description  24 non-null     object
#  3   LogoUrl      24 non-null     object
#  4   school       24 non-null     object
#  5   school_id    24 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 1.2+ KB

# %%
locations.head()
# Out:
#    Unnamed: 0     id             description  country.id country.name  \
# 0           0  15901         Berlin, Germany        57.0      Germany
# 1           1  16022     Mexico City, Mexico        29.0       Mexico
# 2           2  16086  Amsterdam, Netherlands        59.0  Netherlands
# 3           3  16088       Sao Paulo, Brazil        42.0       Brazil
# 4           4  16109           Paris, France        38.0       France
#
#   country.abbrev  city.id    city.name city.keyword  state.id state.name  \
# 0             DE  31156.0       Berlin       berlin       NaN        NaN
# 1             MX  31175.0  Mexico City  mexico-city       NaN        NaN
# 2             NL  31168.0    Amsterdam    amsterdam       NaN        NaN
# 3             BR  31121.0    Sao Paulo    sao-paulo       NaN        NaN
# 4             FR  31136.0        Paris        paris       NaN        NaN
#
#   state.abbrev state.keyword    school  school_id
# 0          NaN           NaN  ironhack      10828
# 1          NaN           NaN  ironhack      10828
# 2          NaN           NaN  ironhack      10828
# 3          NaN           NaN  ironhack      10828
# 4          NaN           NaN  ironhack      10828

# %%
courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  216 non-null    int64
#  1   courses     216 non-null    object
#  2   school      216 non-null    object
#  3   school_id   216 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 6.9+ KB

# %% [markdown]
# It seems we don't need to deal that much with null values. We can decide later
# if we want to remove them or default them to something.
#
# #### Store cleaned up data

# %%
schools.to_csv('schools.csv')
badges.to_csv('badges.csv')
courses.to_csv('courses.csv')
locations.to_csv('locations.csv')
comments.to_csv('comments.csv')

# %% [markdown]
# Data for the schema on the dbdesigner.net
#
#
# badges {
#     name string
#     keyword string
#     description string
#     school string > schools.school
#     school_id number
# }
#
# schools {
#     website string
#     description string
#     LogoUrl string
#     school string
#     school_id number
# }
#
#
# courses {
#     courses string
#     school string > schools.school
#     school_id number
# }
#
# locations {
#    id            number
#    description   string
#    country.id    number
#    country.name  string
#    country.abbrev string
#    city.id        number
#    city.name      string
#    city.keyword   string
#    state.id       number
#    state.name     string
#    state.abbrev   string
#    state.keyword  string
#    school         string > schools.school
#    school_id      number
# }
#
# comments {
#   id               number
#   name            string
#   anonymous       string
#   hostProgramName  string
#   graduatingYear   number
#   isAlumni         string
#   jobTitle         string
#   tagline          string
#   body             string
#   rawBody          string
#   createdAt        string
#   queryDate        string
#   program          string
#   user             string
#   overallScore     number
#  comments         string
#  overall          number
#  curriculum       string
#  jobSupport       string
#  review_body      string
#   school           string > schools.school
# }
